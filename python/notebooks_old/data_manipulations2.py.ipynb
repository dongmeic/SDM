# %%
import matplotlib.pyplot as plt # python graphing library
import numpy as np              # python library for vector/array manipulations
import os                       # interact with the operating system
import pandas as pd             # DataFrame programming in python
from collections import Counter # Tool to track frequencies of items in arrays (lists, sets, etc.)
from pprint import pprint       # "pretty printing" of arrays, dictionaries and JSON objects
from pylab import *             # imaging 

# allow plots to appear in this notebook
# %matplotlib inline              
plt.rcParams['figure.figsize'] = 10, 8 # size of plots

# %%
DATA_PATH = '../../data/dev/'

# %%
clim = pd.read_csv(DATA_PATH + 'climatic_variables_longlat_var.csv')
clim = clim.iloc[:, 1:] # Drop Unnamed: 0 (row index from R: write.csv())

# %%
print(clim.shape)
clim.head()
# Out:
# (999, 682)
#            x        y        lon       lat  mask  etopo1  srtm30  \
# 0  2690000.0 -4510000 -77.292019  5.124395     1      67      78
# 1  2700000.0 -4510000 -77.208582  5.099891     1      61      39
# 2  2710000.0 -4510000 -77.125153  5.075297     1      67      52
# 3  2720000.0 -4510000 -77.041733  5.050615     1      26      22
# 4  2730000.0 -4510000 -76.958322  5.025843     1      43      79
#
#    mat_slice_msk  vgt_mat_msk  btl_mat_msk       ...        btl_vgp_msk.11  \
# 0      25.471111          NaN          NaN       ...                   NaN
# 1      25.745397          NaN          NaN       ...                   NaN
# 2      25.771355          NaN          NaN       ...                   NaN
# 3      26.047372          NaN          NaN       ...                   NaN
# 4      25.815113          NaN          NaN       ...                   NaN
#
#    vgp_slice_msk.12  vgt_vgp_msk.12  btl_vgp_msk.12  vgp_slice_msk.13  \
# 0          0.130108             NaN             NaN          0.470960
# 1          0.147560             NaN             NaN          0.493110
# 2          0.153884             NaN             NaN          0.488933
# 3          0.160750             NaN             NaN          0.485937
# 4          0.171550             NaN             NaN          0.490959
#
#    vgt_vgp_msk.13  btl_vgp_msk.13  vgp_slice_msk.14  vgt_vgp_msk.14  \
# 0             NaN             NaN          0.138894             NaN
# 1             NaN             NaN          0.147905             NaN
# 2             NaN             NaN          0.152029             NaN
# 3             NaN             NaN          0.158797             NaN
# 4             NaN             NaN          0.168400             NaN
#
#    btl_vgp_msk.14
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 682 columns]

# %%
clim = clim.loc[np.isnan(clim['btl_mat_msk']) == False, :]
clim.head()
# Out:
# Empty DataFrame
# Columns: [x, y, lon, lat, mask, etopo1, srtm30, mat_slice_msk, vgt_mat_msk, btl_mat_msk, mat_slice_msk.1, vgt_mat_msk.1, btl_mat_msk.1, mat_slice_msk.2, vgt_mat_msk.2, btl_mat_msk.2, mat_slice_msk.3, vgt_mat_msk.3, btl_mat_msk.3, mat_slice_msk.4, vgt_mat_msk.4, btl_mat_msk.4, mat_slice_msk.5, vgt_mat_msk.5, btl_mat_msk.5, mat_slice_msk.6, vgt_mat_msk.6, btl_mat_msk.6, mat_slice_msk.7, vgt_mat_msk.7, btl_mat_msk.7, mat_slice_msk.8, vgt_mat_msk.8, btl_mat_msk.8, mat_slice_msk.9, vgt_mat_msk.9, btl_mat_msk.9, mat_slice_msk.10, vgt_mat_msk.10, btl_mat_msk.10, mat_slice_msk.11, vgt_mat_msk.11, btl_mat_msk.11, mat_slice_msk.12, vgt_mat_msk.12, btl_mat_msk.12, mat_slice_msk.13, vgt_mat_msk.13, btl_mat_msk.13, mat_slice_msk.14, vgt_mat_msk.14, btl_mat_msk.14, mtaa_slice_msk, vgt_mtaa_msk, btl_mtaa_msk, mtaa_slice_msk.1, vgt_mtaa_msk.1, btl_mtaa_msk.1, mtaa_slice_msk.2, vgt_mtaa_msk.2, btl_mtaa_msk.2, mtaa_slice_msk.3, vgt_mtaa_msk.3, btl_mtaa_msk.3, mtaa_slice_msk.4, vgt_mtaa_msk.4, btl_mtaa_msk.4, mtaa_slice_msk.5, vgt_mtaa_msk.5, btl_mtaa_msk.5, mtaa_slice_msk.6, vgt_mtaa_msk.6, btl_mtaa_msk.6, mtaa_slice_msk.7, vgt_mtaa_msk.7, btl_mtaa_msk.7, mtaa_slice_msk.8, vgt_mtaa_msk.8, btl_mtaa_msk.8, mtaa_slice_msk.9, vgt_mtaa_msk.9, btl_mtaa_msk.9, mtaa_slice_msk.10, vgt_mtaa_msk.10, btl_mtaa_msk.10, mtaa_slice_msk.11, vgt_mtaa_msk.11, btl_mtaa_msk.11, mtaa_slice_msk.12, vgt_mtaa_msk.12, btl_mtaa_msk.12, mtaa_slice_msk.13, vgt_mtaa_msk.13, btl_mtaa_msk.13, mtaa_slice_msk.14, vgt_mtaa_msk.14, btl_mtaa_msk.14, mta_slice_msk, vgt_mta_msk, btl_mta_msk, ...]
# Index: []
#
# [0 rows x 682 columns]

# %% [markdown]
# # Eliminate column redundancy
# **Variable key**
# * `cpja:`&nbsp;&nbsp;&nbsp;cumulative precipitation from June to August in current and previous year; use precipitation data in the previous and current year
# * `cpos:`&nbsp;&nbsp;&nbsp;cumulative precipitation from October to September in current and previous year
# * `gsp:`&nbsp;&nbsp;&nbsp;&nbsp;growing season precipitation in current year
# * `map:`&nbsp;&nbsp;&nbsp;&nbsp;mean annual precipitation; use precipitation data from January to December in the past five years
# * `mat:`&nbsp;&nbsp;&nbsp;&nbsp;annual mean monthly average of daily mean temperature in the past year
# * `mta:`&nbsp;&nbsp;&nbsp;&nbsp;monthly average of daily mean temperature in August
# * `mtaa:`&nbsp;&nbsp;&nbsp;mean of monthly average of daily mean temperature from April to August
# * `ntj:`&nbsp;&nbsp;&nbsp;&nbsp;monthly average of daily minimum temperature in January
# * `ntm:`&nbsp;&nbsp;&nbsp;&nbsp;monthly average of daily minimum temperature in March
# * `nto:`&nbsp;&nbsp;&nbsp;&nbsp;monthly average of daily minimum temperature in October
# * `ntw:`&nbsp;&nbsp;&nbsp;&nbsp;minimum of monthly average of daily minimum temperature between Dec and Feb
# * `pja:`&nbsp;&nbsp;&nbsp;&nbsp;precipitation from June to August in previous year
# * `pos:`&nbsp;&nbsp;&nbsp;&nbsp;precipitation from October to September in previous year
# * `vgp:`&nbsp;&nbsp;&nbsp;&nbsp;variability of growing season precipitation
# * `xta:`&nbsp;&nbsp;&nbsp;&nbsp;monthly average of daily maximum temperature in August

# %%
# Reorganize columns in alphabetic order
sorted_cols = sorted(list(clim))
clim = clim[sorted_cols]
clim.head()
# Out:
#    btl_cpja_msk  btl_cpja_msk.1  btl_cpja_msk.10  btl_cpja_msk.11  \
# 0           NaN             NaN              NaN              NaN
# 1           NaN             NaN              NaN              NaN
# 2           NaN             NaN              NaN              NaN
# 3           NaN             NaN              NaN              NaN
# 4           NaN             NaN              NaN              NaN
#
#    btl_cpja_msk.12  btl_cpja_msk.13  btl_cpja_msk.14  btl_cpja_msk.2  \
# 0              NaN              NaN              NaN             NaN
# 1              NaN              NaN              NaN             NaN
# 2              NaN              NaN              NaN             NaN
# 3              NaN              NaN              NaN             NaN
# 4              NaN              NaN              NaN             NaN
#
#    btl_cpja_msk.3  btl_cpja_msk.4   ...     xta_slice_msk.14  xta_slice_msk.2  \
# 0             NaN             NaN   ...            30.876667        29.226667
# 1             NaN             NaN   ...            31.199392        29.568858
# 2             NaN             NaN   ...            31.303671        29.711732
# 3             NaN             NaN   ...            31.707875        30.153704
# 4             NaN             NaN   ...            31.612004        30.094766
#
#    xta_slice_msk.3  xta_slice_msk.4  xta_slice_msk.5  xta_slice_msk.6  \
# 0        29.976667        28.776666        29.426666        29.176667
# 1        30.325272        29.121031        29.820832        29.525585
# 2        30.426127        29.242350        30.013458        29.654233
# 3        30.826926        29.665251        30.506019        30.081989
# 4        30.727668        29.589740        30.498513        30.008847
#
#    xta_slice_msk.7  xta_slice_msk.8  xta_slice_msk.9        y
# 0        28.176667        29.326667        30.876667 -4510000
# 1        28.527974        29.675272        31.221130 -4510000
# 2        28.691666        29.776126        31.313642 -4510000
# 3        29.157751        30.176926        31.706099 -4510000
# 4        29.126240        30.077667        31.598499 -4510000
#
# [5 rows x 682 columns]

# %% [markdown]
# ### 1. Keep Only a Single Beetle and Vegetation Mask (per year)

# %%
def reduce_mask_to_single(mask, dataframe):
    assert mask in ['btl', 'vgt']

    df = dataframe.copy()
    drop_cols = [field for field in list(df) 
                 if field.startswith(mask) and '_cpja_' not in field]
    df = df.drop(drop_cols, axis=1)
    return df

# %%
def mask_to_binary(mask, dataframe):
    assert mask in ['btl', 'vgt', 'mask']
    
    df = dataframe.copy()
    for col in list(df):
        if col.startswith(mask):
            df[col] = df[col].apply(lambda x: 0 if np.isnan(x) else 1)
            
    return df

# %%
def reduce_masks(masks, dataframe):
    df = dataframe.copy()
    
    for mask in masks:
        df = reduce_mask_to_single(mask, df)
        df = mask_to_binary(mask, df)
        
    return df

# %%
clim = reduce_masks(['btl', 'vgt'], clim)
clim = mask_to_binary('mask', clim)

# %%
for field in list(clim):
    print('{:<25}'.format(field), end='')
# Out:
# btl_cpja_msk             btl_cpja_msk.1           btl_cpja_msk.10          btl_cpja_msk.11          btl_cpja_msk.12          btl_cpja_msk.13          btl_cpja_msk.14          btl_cpja_msk.2           btl_cpja_msk.3           btl_cpja_msk.4           btl_cpja_msk.5           btl_cpja_msk.6           btl_cpja_msk.7           btl_cpja_msk.8           btl_cpja_msk.9           cpja_slice_msk           cpja_slice_msk.1         cpja_slice_msk.10        cpja_slice_msk.11        cpja_slice_msk.12        cpja_slice_msk.13        cpja_slice_msk.14        cpja_slice_msk.2         cpja_slice_msk.3         cpja_slice_msk.4         cpja_slice_msk.5         cpja_slice_msk.6         cpja_slice_msk.7         cpja_slice_msk.8         cpja_slice_msk.9         cpos_slice_msk           cpos_slice_msk.1         cpos_slice_msk.10        cpos_slice_msk.11        cpos_slice_msk.12        cpos_slice_msk.13        cpos_slice_msk.14        cpos_slice_msk.2         cpos_slice_msk.3         cpos_slice_msk.4         cpos_slice_msk.5         cpos_slice_msk.6         cpos_slice_msk.7         cpos_slice_msk.8         cpos_slice_msk.9         etopo1                   gsp_slice_msk            gsp_slice_msk.1          gsp_slice_msk.10         gsp_slice_msk.11         gsp_slice_msk.12         gsp_slice_msk.13         gsp_slice_msk.14         gsp_slice_msk.2          gsp_slice_msk.3          gsp_slice_msk.4          gsp_slice_msk.5          gsp_slice_msk.6          gsp_slice_msk.7          gsp_slice_msk.8          gsp_slice_msk.9          lat                      lon                      map_slice_msk            map_slice_msk.1          map_slice_msk.10         map_slice_msk.11         map_slice_msk.12         map_slice_msk.13         map_slice_msk.14         map_slice_msk.2          map_slice_msk.3          map_slice_msk.4          map_slice_msk.5          map_slice_msk.6          map_slice_msk.7          map_slice_msk.8          map_slice_msk.9          mask                     mat_slice_msk            mat_slice_msk.1          mat_slice_msk.10         mat_slice_msk.11         mat_slice_msk.12         mat_slice_msk.13         mat_slice_msk.14         mat_slice_msk.2          mat_slice_msk.3          mat_slice_msk.4          mat_slice_msk.5          mat_slice_msk.6          mat_slice_msk.7          mat_slice_msk.8          mat_slice_msk.9          mta_slice_msk            mta_slice_msk.1          mta_slice_msk.10         mta_slice_msk.11         mta_slice_msk.12         mta_slice_msk.13         mta_slice_msk.14         mta_slice_msk.2          mta_slice_msk.3          mta_slice_msk.4          mta_slice_msk.5          mta_slice_msk.6          mta_slice_msk.7          mta_slice_msk.8          mta_slice_msk.9          mtaa_slice_msk           mtaa_slice_msk.1         mtaa_slice_msk.10        mtaa_slice_msk.11        mtaa_slice_msk.12        mtaa_slice_msk.13        mtaa_slice_msk.14        mtaa_slice_msk.2         mtaa_slice_msk.3         mtaa_slice_msk.4         mtaa_slice_msk.5         mtaa_slice_msk.6         mtaa_slice_msk.7         mtaa_slice_msk.8         mtaa_slice_msk.9         ntj_slice_msk            ntj_slice_msk.1          ntj_slice_msk.10         ntj_slice_msk.11         ntj_slice_msk.12         ntj_slice_msk.13         ntj_slice_msk.14         ntj_slice_msk.2          ntj_slice_msk.3          ntj_slice_msk.4          ntj_slice_msk.5          ntj_slice_msk.6          ntj_slice_msk.7          ntj_slice_msk.8          ntj_slice_msk.9          ntm_slice_msk            ntm_slice_msk.1          ntm_slice_msk.10         ntm_slice_msk.11         ntm_slice_msk.12         ntm_slice_msk.13         ntm_slice_msk.14         ntm_slice_msk.2          ntm_slice_msk.3          ntm_slice_msk.4          ntm_slice_msk.5          ntm_slice_msk.6          ntm_slice_msk.7          ntm_slice_msk.8          ntm_slice_msk.9          nto_slice_msk            nto_slice_msk.1          nto_slice_msk.10         nto_slice_msk.11         nto_slice_msk.12         nto_slice_msk.13          ...

# %%
static_fields = ['etopo1', 'lat', 'lon', 'mask', 'srtm30', 'x', 'y']
static_df = clim[static_fields]
clim = clim.drop(static_fields, axis=1)
static_df.head()
# Out:
#    etopo1       lat        lon  mask  srtm30          x        y
# 0      67  5.124395 -77.292019     1      78  2690000.0 -4510000
# 1      61  5.099891 -77.208582     1      39  2700000.0 -4510000
# 2      67  5.075297 -77.125153     1      52  2710000.0 -4510000
# 3      26  5.050615 -77.041733     1      22  2720000.0 -4510000
# 4      43  5.025843 -76.958322     1      79  2730000.0 -4510000

# %%
#yearly_data = [field for field in list(clim) if field not in static_fields]

# %%
def make_single_year_dataframe(source_df, year, static_df, verbose=True):
    static = static_df.copy()
    n = source_df.shape[0]
    year_col = [year] * n
    
    df = pd.DataFrame(index=range(n), data=year_col, columns=['year'])
    for field in list(source_df):
        if field.endswith('.%s' % (year - 2000)):
            simple_field = field.split('.')[0]
            if 'btl' in simple_field:
                simple_field = 'beetle'
            elif 'vgt' in simple_field:
                simple_field = 'vegetation'
            df[simple_field] = source_df.pop(field)
        elif '.' not in field and year == 2000:
            simple_field = field
            if 'btl' in field:
                simple_field = 'beetle'
            elif 'vgt' in field:
                simple_field = 'vegetation'
            df[simple_field] = source_df.pop(field)
            
    for field in static:
        df[field] = static[field]
        
    if verbose:
        print('Dataframe for %d has dimensions:' % year, df.shape)

    return df, source_df

# %%
EARLIEST_YEAR = 2000
LATEST_YEAR   = 2014

dfs = []
source_df = clim.copy()

for year in range(EARLIEST_YEAR + 1, LATEST_YEAR + 1):
    df, source_df = make_single_year_dataframe(source_df, year, static_df)
    dfs.append(df)
# Out:
# Dataframe for 2001 has dimensions: (999, 25)
# Dataframe for 2002 has dimensions: (999, 25)
# Dataframe for 2003 has dimensions: (999, 25)
# Dataframe for 2004 has dimensions: (999, 25)
# Dataframe for 2005 has dimensions: (999, 25)
# Dataframe for 2006 has dimensions: (999, 25)
# Dataframe for 2007 has dimensions: (999, 25)
# Dataframe for 2008 has dimensions: (999, 25)
# Dataframe for 2009 has dimensions: (999, 25)
# Dataframe for 2010 has dimensions: (999, 25)
# Dataframe for 2011 has dimensions: (999, 25)
# Dataframe for 2012 has dimensions: (999, 25)
# Dataframe for 2013 has dimensions: (999, 25)
# Dataframe for 2014 has dimensions: (999, 25)

# %%
df2000, _ = make_single_year_dataframe(source_df, 2000, static_df)
# Out:
# Dataframe for 2000 has dimensions: (999, 25)

# %%
dfs[0].head()
# Out:
#    year  beetle  cpja_slice_msk  cpos_slice_msk  gsp_slice_msk  map_slice_msk  \
# 0  2001       0     3934.760092    16003.033496    1942.879970     608.901388
# 1  2001       0     3934.991342    16243.177809    1958.681898     612.592116
# 2  2001       0     3921.424975    16392.949292    1983.605426     618.470977
# 3  2001       0     3917.562807    16609.697930    2013.234559     627.050481
# 4  2001       0     3841.403413    16587.418553    2012.562594     625.579962
#
#    mat_slice_msk  mta_slice_msk  mtaa_slice_msk  ntj_slice_msk   ...     \
# 0      26.012778      26.716666       26.402667      22.310000   ...
# 1      26.278177      27.014215       26.681262      22.529585   ...
# 2      26.300125      27.014836       26.677809      22.278339   ...
# 3      26.572127      27.315456       26.954387      22.427825   ...
# 4      26.335849      27.116072       26.730996      22.078050   ...
#
#    vgp_slice_msk  vegetation  xta_slice_msk  etopo1       lat        lon  \
# 0       0.700038           0      30.676666      67  5.124395 -77.292019
# 1       0.621698           0      31.025271      61  5.099891 -77.208582
# 2       0.603099           0      31.126126      67  5.075297 -77.125153
# 3       0.579787           0      31.526926      26  5.050615 -77.041733
# 4       0.564186           0      31.427668      43  5.025843 -76.958322
#
#    mask  srtm30          x        y
# 0     1      78  2690000.0 -4510000
# 1     1      39  2700000.0 -4510000
# 2     1      52  2710000.0 -4510000
# 3     1      22  2720000.0 -4510000
# 4     1      79  2730000.0 -4510000
#
# [5 rows x 25 columns]

# %%
dfs[3].head()
# Out:
#    year  beetle  cpja_slice_msk  cpos_slice_msk  gsp_slice_msk  map_slice_msk  \
# 0  2004       0     4769.159949    13803.833209    1186.179958     496.834718
# 1  2004       0     4681.767990    13994.521661    1229.708977     511.039048
# 2  2004       0     4640.946819    14114.520143    1264.406511     518.730637
# 3  2004       0     4608.549866    14302.912326    1306.032120     529.428124
# 4  2004       0     4502.569240    14253.700575    1319.590685     530.382409
#
#    mat_slice_msk  mta_slice_msk  mtaa_slice_msk  ntj_slice_msk   ...     \
# 0      26.096111      26.316666       26.302666      24.610000   ...
# 1      26.362839      26.578397       26.586107      24.855876   ...
# 2      26.382936      26.563651       26.581548      24.600192   ...
# 3      26.653225      26.850536       26.857353      24.742787   ...
# 4      26.415375      26.639058       26.633525      24.383652   ...
#
#    vgp_slice_msk  vegetation  xta_slice_msk  etopo1       lat        lon  \
# 0       0.259350           0      28.776666      67  5.124395 -77.292019
# 1       0.250646           0      29.121031      61  5.099891 -77.208582
# 2       0.250628           0      29.242350      67  5.075297 -77.125153
# 3       0.252608           0      29.665251      26  5.050615 -77.041733
# 4       0.259726           0      29.589740      43  5.025843 -76.958322
#
#    mask  srtm30          x        y
# 0     1      78  2690000.0 -4510000
# 1     1      39  2700000.0 -4510000
# 2     1      52  2710000.0 -4510000
# 3     1      22  2720000.0 -4510000
# 4     1      79  2730000.0 -4510000
#
# [5 rows x 25 columns]

# %%
df_out = df2000
for df in dfs:
    df_out = df_out.append(df)

# %%
df_out.head()
# Out:
#    year  beetle  cpja_slice_msk  cpos_slice_msk  gsp_slice_msk  map_slice_msk  \
# 0  2000       0     3971.260092    16926.433521    1853.980037     724.684736
# 1  2000       0     4016.543298    17314.546932    1902.055382     741.006035
# 2  2000       0     4011.466088    17479.006607    1928.846500     747.608131
# 3  2000       0     4016.515126    17712.944850    1962.336310     757.091013
# 4  2000       0     3949.691058    17710.369112    1967.528453     756.704917
#
#    mat_slice_msk  mta_slice_msk  mtaa_slice_msk  ntj_slice_msk   ...     \
# 0      25.471111      25.816666       25.722666      21.410000   ...
# 1      25.745397      26.114216       26.021594      21.608876   ...
# 2      25.771355      26.114836       26.025271      21.315915   ...
# 3      26.047372      26.415456       26.308330      21.423692   ...
# 4      25.815113      26.216072       26.090767      21.032211   ...
#
#    vgp_slice_msk  vegetation  xta_slice_msk  etopo1       lat        lon  \
# 0       0.314621           0      29.776666      67  5.124395 -77.292019
# 1       0.309427           0      30.154264      61  5.099891 -77.208582
# 2       0.302973           0      30.313519      67  5.075297 -77.125153
# 3       0.297781           0      30.772712      26  5.050615 -77.041733
# 4       0.296310           0      30.731842      43  5.025843 -76.958322
#
#    mask  srtm30          x        y
# 0     1      78  2690000.0 -4510000
# 1     1      39  2700000.0 -4510000
# 2     1      52  2710000.0 -4510000
# 3     1      22  2720000.0 -4510000
# 4     1      79  2730000.0 -4510000
#
# [5 rows x 25 columns]

# %%
print(999 * 15)
df_out.shape
# Out:
# 14985
# (14985, 25)

# %%
predictor_name_map = {
    'cpja_slice_msk': 'precip_JunAug',
    'cpos_slice_msk': 'precip_OctSep',
    'gsp_slice_msk':  'precip_growingSeason',
    'map_slice_msk':  'precip_meanAnnual',
    'mat_slice_msk':  'meanTemp_Annual',
    'mta_slice_msk':  'meanTemp_Aug',
    'mtaa_slice_msk': 'meanTemp_AprAug',
    'ntj_slice_msk':  'meanMinTemp_Jan',
    'ntm_slice_msk':  'meanMinTemp_Mar',
    'nto_slice_msk':  'meanMinTemp_Oct',
    'ntw_slice_msk':  'meanMinTemp_DecFeb',
    'pja_slice_msk':  'precipPrevious_JunAug',
    'pos_slice_msk':  'precipPreious_OctSep',
    'vgp_slice_msk':  'varPrecip_growingSeason',
    'xta_slice_msk':  'meanMaxTemp_Aug',
    'etopo1':         'elev_etopo1',
    'srtm30':         'elev_srtm30',
    'mask':           'studyArea'}

# %%
df = df.rename(columns=predictor_name_map)
df.head()
# Out:
#    year  beetle  precip_JunAug  precip_OctSep  precip_growingSeason  \
# 0  2014       0    2577.260016   12906.033359           1364.280025
# 1  2014       0    2594.673175   13220.560694           1429.550831
# 2  2014       0    2615.540579   13418.755609           1459.028055
# 3  2014       0    2648.110790   13688.704153           1495.428626
# 4  2014       0    2610.392888   13724.426062           1503.757309
#
#    precip_meanAnnual  meanTemp_Annual  meanTemp_Aug  meanTemp_AprAug  \
# 0         535.318058        26.812778     26.916667        27.142666
# 1         547.503372        27.079143     27.184194        27.427266
# 2         555.477352        27.102833     27.179896        27.424797
# 3         566.427592        27.376301     27.475579        27.702362
# 4         567.604844        27.141213     27.271241        27.479962
#
#    meanMinTemp_Jan   ...     varPrecip_growingSeason  vegetation  \
# 0        23.260000   ...                    0.138894           0
# 1        23.556822   ...                    0.147905           0
# 2        23.404371   ...                    0.152029           0
# 3        23.651013   ...                    0.158797           0
# 4        23.396743   ...                    0.168400           0
#
#    meanMaxTemp_Aug  elev_etopo1       lat        lon  studyArea  elev_srtm30  \
# 0        30.876667           67  5.124395 -77.292019          1           78
# 1        31.199392           61  5.099891 -77.208582          1           39
# 2        31.303671           67  5.075297 -77.125153          1           52
# 3        31.707875           26  5.050615 -77.041733          1           22
# 4        31.612004           43  5.025843 -76.958322          1           79
#
#            x        y
# 0  2690000.0 -4510000
# 1  2700000.0 -4510000
# 2  2710000.0 -4510000
# 3  2720000.0 -4510000
# 4  2730000.0 -4510000
#
# [5 rows x 25 columns]

# %%
list(df)
# Out:
# ['year',
#  'beetle',
#  'precip_JunAug',
#  'precip_OctSep',
#  'precip_growingSeason',
#  'precip_meanAnnual',
#  'meanTemp_Annual',
#  'meanTemp_Aug',
#  'meanTemp_AprAug',
#  'meanMinTemp_Jan',
#  'meanMinTemp_Mar',
#  'meanMinTemp_Oct',
#  'meanMinTemp_DecFeb',
#  'precipPrevious_JunAug',
#  'precipPreious_OctSep',
#  'varPrecip_growingSeason',
#  'vegetation',
#  'meanMaxTemp_Aug',
#  'elev_etopo1',
#  'lat',
#  'lon',
#  'studyArea',
#  'elev_srtm30',
#  'x',
#  'y']
