# %%
import keras
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import sys
import time
from keras.callbacks import EarlyStopping, ModelCheckpoint 
from keras.layers import Activation, BatchNormalization, Dense, Dropout
from keras.models import Sequential
from keras.optimizers import Adam
from pprint import pprint
from pylab import *
from sklearn.preprocessing import StandardScaler

sys.path.append('..')
import model_utils as util
sys.path.append('../..')
import data_manipulations as manip

# %matplotlib inline

plt.rcParams['figure.figsize'] = 10, 8
plt.style.use('ggplot')
# Out:
# Using TensorFlow backend.

# %%
DATA_PATH =  '../../../data/cluster/year/'
[f for f in os.listdir(DATA_PATH) if 'full' in f]
# Out:
# ['X_test_full.csv',
#  'X_train_full.csv',
#  'X_valid_full.csv',
#  'y_test_full.csv',
#  'y_train_full.csv',
#  'y_valid_full.csv']

# %%
X_train = pd.read_csv(DATA_PATH + 'X_train_full.csv')
X_valid = pd.read_csv(DATA_PATH + 'X_valid_full.csv')
X_test  = pd.read_csv(DATA_PATH + 'X_test_full.csv')
y_train = pd.read_csv(DATA_PATH + 'y_train_full.csv')
y_valid = pd.read_csv(DATA_PATH + 'y_valid_full.csv')
y_test  = pd.read_csv(DATA_PATH + 'y_test_full.csv')

X_train = X_train.drop(['Unnamed: 0'], axis=1)
X_valid = X_valid.drop(['Unnamed: 0'], axis=1)
X_test  = X_test.drop(['Unnamed: 0'],  axis=1)
y_train = y_train.drop(['Unnamed: 0'], axis=1)
y_valid = y_valid.drop(['Unnamed: 0'], axis=1)
y_test  = y_test.drop(['Unnamed: 0'],  axis=1)


print('train: X %s\t y%s' % (X_train.shape, y_train.shape))
print('valid: X %s\t y%s' % (X_valid.shape, y_valid.shape))
print('test:  X %s\t y%s' % (X_test.shape,  y_test.shape))
# Out:
# train: X (529623, 25)	 y(529623, 1)
# valid: X (117694, 25)	 y(117694, 1)
# test:  X (117694, 25)	 y(117694, 1)

# %%
util.print_percent_presence(y_train, 'y_train')
util.print_percent_presence(y_valid, 'y_valid')
util.print_percent_presence(y_test,  'y_test')
# Out:
# Percent presence in y_train: 17.23%
# Percent presence in y_valid: 13.29%
# Percent presence in y_test: 12.54%

# %%
print('Baseline accuracy if predicting "absent" for all cells:')
print('  train:', 100 - 17.26)
print('  valid:', 100 - 13.92)
print('  test: ', 100 - 12.64)
# Out:
# Baseline accuracy if predicting "absent" for all cells:
#   train: 82.74
#   valid: 86.08
#   test:  87.36

# %%
np.isfinite(X_valid).all()
# Out:
# year                        True
# meanTemp_Annual             True
# meanTemp_AprAug             True
# meanTemp_Aug                True
# meanMinTemp_DecFeb          True
# meanMinTemp_Oct             True
# meanMinTemp_Jan             True
# meanMinTemp_Mar             True
# meanMaxTemp_Aug             True
# precip_meanAnnual           True
# precip_JunAug               True
# vegetation                  True
# precipPrevious_JunAug       True
# precip_OctSep               True
# precipPrevious_OctSep       True
# precip_growingSeason        True
# varPrecip_growingSeason    False
# elev_etopo1                 True
# lat                         True
# lon                         True
# studyArea                   True
# elev_srtm30                 True
# x                           True
# y                           True
# next_year_beetle            True
# dtype: bool

# %%
print('X_train:', 
      np.isnan(X_train.varPrecip_growingSeason).sum() / X_train.shape[0])
print('X_valid:', 
      np.isnan(X_valid.varPrecip_growingSeason).sum() / X_valid.shape[0])
print('X_test:',  
      np.isnan(X_test.varPrecip_growingSeason).sum() / X_test.shape[0])
# Out:
# X_train: 0.00350626766587
# X_valid: 0.00817373867827
# X_test: 0.00188624738729

# %%
X_train, y_train = util.drop_nans(
    X_train, y_train, 'varPrecip_growingSeason')
X_valid, y_valid = util.drop_nans(
    X_valid, y_valid, 'varPrecip_growingSeason')
X_test,  y_test  = util.drop_nans(
    X_test,  y_test,  'varPrecip_growingSeason')
# Out:
# (527766, 25) (527766, 1)
# (116732, 25) (116732, 1)
# (117472, 25) (117472, 1)

# %%
full_test = X_test.copy()
full_test['beetle'] = y_test['beetle']

# %%
# Drop 'studyArea' from predictors (all 1 in the reduced data) and 'x' and
# 'y' (perfectly correlated with 'lon' and 'lat')
X_train = X_train.drop(['studyArea', 'x', 'y', 'elev_srtm30', 'year'], axis=1)
X_valid = X_valid.drop(['studyArea', 'x', 'y', 'elev_srtm30', 'year'], axis=1)
X_test  = X_test.drop(['studyArea',  'x', 'y', 'elev_srtm30', 'year'],  axis=1)

# %%
predictors = list(X_train)
predictors
# Out:
# ['meanTemp_Annual',
#  'meanTemp_AprAug',
#  'meanTemp_Aug',
#  'meanMinTemp_DecFeb',
#  'meanMinTemp_Oct',
#  'meanMinTemp_Jan',
#  'meanMinTemp_Mar',
#  'meanMaxTemp_Aug',
#  'precip_meanAnnual',
#  'precip_JunAug',
#  'vegetation',
#  'precipPrevious_JunAug',
#  'precip_OctSep',
#  'precipPrevious_OctSep',
#  'precip_growingSeason',
#  'varPrecip_growingSeason',
#  'elev_etopo1',
#  'lat',
#  'lon',
#  'next_year_beetle']

# %%
# Normalize data to make gradient descent more efficient
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_valid = scaler.transform(X_valid)
X_test  = scaler.transform(X_test)

# %%
y_train = util.vectorize(y_train.as_matrix())
y_valid = util.vectorize(y_valid.as_matrix())
y_test  = util.vectorize(y_test.as_matrix())

# %% [markdown]
# # Neural Net Model

# %%
best_val_loss = np.inf
X_train.shape
# Out:
# (527766, 20)

# %%
# Params and Hyperparams
n_inputs = X_train.shape[1]
n_outputs = 2

# Current best
#N_LAYERS = 3
#NODES_PER_LAYER = ([n_inputs] * N_LAYERS)
NODES_PER_LAYER = [
    n_inputs, n_inputs * 2, n_inputs * 4, n_inputs * 8, n_inputs * 8, 
    n_inputs * 8, n_inputs * 8, n_inputs * 8, n_inputs * 4, n_inputs * 2, 
    n_inputs]
NODES_PER_LAYER.append(n_outputs)
ETA = 0.1
DROPOUT = 0.5
BETA_1 = 0.9
BETA_2 = 0.999
EPSILON = 1e-08
DECAY = 0.01
EPOCHS = 124
BATCH_SIZE = 1024

NODES_PER_LAYER
# Out:
# [20, 40, 80, 160, 160, 160, 160, 160, 80, 40, 20, 2]

# %%
def get_params():
    return {'NODES_PER_LAYER': NODES_PER_LAYER,
            'ETA': ETA,
            'DROPOUT': DROPOUT,
            'BETA_1': BETA_1,
            'BETA_2': BETA_2,
            'EPSILON': EPSILON,
            'DECAY': DECAY,
            'EPOCHS': EPOCHS,
            'BATCH_SIZE': BATCH_SIZE}

# %%
model = Sequential()

# NOTE: "glorot-normal" is the same thing as "Xavier" initialization
model.add(Dense(NODES_PER_LAYER[1], 
                input_dim=NODES_PER_LAYER[0], 
                kernel_initializer='glorot_normal'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(DROPOUT))

# additional hidden layers here
for i in range(2, len(NODES_PER_LAYER) - 1):
    model.add(Dense(NODES_PER_LAYER[i], 
                    kernel_initializer='glorot_normal'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dropout(DROPOUT))

model.add(Dense(NODES_PER_LAYER[-1], kernel_initializer='glorot_normal'))
model.add(BatchNormalization())
model.add(Activation('softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 40)                840
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 40)                160
# _________________________________________________________________
# activation_1 (Activation)    (None, 40)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 40)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 80)                3280
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 80)                320
# _________________________________________________________________
# activation_2 (Activation)    (None, 80)                0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 80)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 160)               12960
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 160)               640
# _________________________________________________________________
# activation_3 (Activation)    (None, 160)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 160)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 160)               25760
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 160)               640
# _________________________________________________________________
# activation_4 (Activation)    (None, 160)               0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 160)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 160)               25760
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 160)               640
# _________________________________________________________________
# activation_5 (Activation)    (None, 160)               0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 160)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 160)               25760
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 160)               640
# _________________________________________________________________
# activation_6 (Activation)    (None, 160)               0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 160)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 160)               25760
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 160)               640
# _________________________________________________________________
# activation_7 (Activation)    (None, 160)               0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 160)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 80)                12880
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 80)                320
# _________________________________________________________________
# activation_8 (Activation)    (None, 80)                0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 80)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 40)                3240
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 40)                160
# _________________________________________________________________
# activation_9 (Activation)    (None, 40)                0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 40)                0
# _________________________________________________________________
# dense_10 (Dense)             (None, 20)                820
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 20)                80
# _________________________________________________________________
# activation_10 (Activation)   (None, 20)                0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 20)                0
# _________________________________________________________________
# dense_11 (Dense)             (None, 2)                 42
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 2)                 8
# _________________________________________________________________
# activation_11 (Activation)   (None, 2)                 0
# =================================================================
# Total params: 141,350
# Trainable params: 139,226
# Non-trainable params: 2,124
# _________________________________________________________________

# %%
adam = Adam(
    lr=ETA, beta_1=BETA_1, beta_2=BETA_2, epsilon=EPSILON, decay=DECAY)
model.compile(
    loss='binary_crossentropy', optimizer=adam, metrics=['accuracy'])

# %%
VERBOSE = 1
checkpointer = ModelCheckpoint(filepath=DATA_PATH + 'weights.bestNN.hdf5',
                               verbose=VERBOSE,
                               save_best_only=True)
earlyStop = EarlyStopping(monitor='val_loss', patience=EPOCHS / 2)
start = time.time()
history = model.fit(X_train,
                    y_train,
                    validation_data=(X_valid, y_valid),
                    epochs=EPOCHS,
                    batch_size=BATCH_SIZE,
                    callbacks=[checkpointer], #, earlyStop],
                    verbose=VERBOSE)
elapsed = time.time() - start
print('Time: %.2f minutes' % (elapsed / 60))
# Out:
# Train on 527766 samples, validate on 116732 samples
# Epoch 1/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2422 - acc: 0.9127Epoch 00001: val_loss improved from inf to 0.21598, saving model to ../../../data/cluster/year/weights.bestNN.hdf5
# 527766/527766 [==============================] - 74s 139us/step - loss: 0.2422 - acc: 0.9127 - val_loss: 0.2160 - val_acc: 0.9278
# Epoch 2/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2360 - acc: 0.9149Epoch 00002: val_loss did not improve
# 527766/527766 [==============================] - 72s 137us/step - loss: 0.2360 - acc: 0.9149 - val_loss: 0.2303 - val_acc: 0.9289
# Epoch 3/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2326 - acc: 0.9164Epoch 00003: val_loss did not improve
# 527766/527766 [==============================] - 74s 140us/step - loss: 0.2325 - acc: 0.9165 - val_loss: 0.2307 - val_acc: 0.9268
# Epoch 4/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2302 - acc: 0.9170Epoch 00004: val_loss did not improve
# 527766/527766 [==============================] - 73s 139us/step - loss: 0.2302 - acc: 0.9170 - val_loss: 0.2319 - val_acc: 0.9260
# Epoch 5/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2292 - acc: 0.9176Epoch 00005: val_loss did not improve
# 527766/527766 [==============================] - 74s 140us/step - loss: 0.2292 - acc: 0.9176 - val_loss: 0.2408 - val_acc: 0.9273
# Epoch 6/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2281 - acc: 0.9180Epoch 00006: val_loss did not improve
# 527766/527766 [==============================] - 74s 141us/step - loss: 0.2281 - acc: 0.9180 - val_loss: 0.2353 - val_acc: 0.9269
# Epoch 7/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2263 - acc: 0.9188Epoch 00007: val_loss did not improve
# 527766/527766 [==============================] - 75s 141us/step - loss: 0.2263 - acc: 0.9188 - val_loss: 0.2374 - val_acc: 0.9276
# Epoch 8/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2250 - acc: 0.9187Epoch 00008: val_loss did not improve
# 527766/527766 [==============================] - 75s 143us/step - loss: 0.2250 - acc: 0.9187 - val_loss: 0.2298 - val_acc: 0.9275
# Epoch 9/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2249 - acc: 0.9184Epoch 00009: val_loss did not improve
# 527766/527766 [==============================] - 77s 146us/step - loss: 0.2248 - acc: 0.9184 - val_loss: 0.2386 - val_acc: 0.9260
# Epoch 10/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2246 - acc: 0.9184Epoch 00010: val_loss did not improve
# 527766/527766 [==============================] - 75s 143us/step - loss: 0.2245 - acc: 0.9184 - val_loss: 0.2373 - val_acc: 0.9245
# Epoch 11/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2242 - acc: 0.9191Epoch 00011: val_loss did not improve
# 527766/527766 [==============================] - 75s 143us/step - loss: 0.2242 - acc: 0.9191 - val_loss: 0.2364 - val_acc: 0.9266
# Epoch 12/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2223 - acc: 0.9190Epoch 00012: val_loss did not improve
# 527766/527766 [==============================] - 76s 143us/step - loss: 0.2223 - acc: 0.9190 - val_loss: 0.2401 - val_acc: 0.9258
# Epoch 13/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2223 - acc: 0.9196Epoch 00013: val_loss did not improve
# 527766/527766 [==============================] - 76s 145us/step - loss: 0.2223 - acc: 0.9195 - val_loss: 0.2389 - val_acc: 0.9258
# Epoch 14/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2223 - acc: 0.9198Epoch 00014: val_loss did not improve
# 527766/527766 [==============================] - 76s 145us/step - loss: 0.2223 - acc: 0.9198 - val_loss: 0.2356 - val_acc: 0.9259
# Epoch 15/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2217 - acc: 0.9194Epoch 00015: val_loss did not improve
# 527766/527766 [==============================] - 58s 110us/step - loss: 0.2217 - acc: 0.9194 - val_loss: 0.2439 - val_acc: 0.9254
# Epoch 16/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2211 - acc: 0.9191Epoch 00016: val_loss did not improve
# 527766/527766 [==============================] - 59s 111us/step - loss: 0.2210 - acc: 0.9191 - val_loss: 0.2371 - val_acc: 0.9256
# Epoch 17/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2211 - acc: 0.9195Epoch 00017: val_loss did not improve
# 527766/527766 [==============================] - 59s 112us/step - loss: 0.2210 - acc: 0.9195 - val_loss: 0.2413 - val_acc: 0.9259
# Epoch 18/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2208 - acc: 0.9193Epoch 00018: val_loss did not improve
# 527766/527766 [==============================] - 61s 116us/step - loss: 0.2209 - acc: 0.9193 - val_loss: 0.2423 - val_acc: 0.9254
# Epoch 19/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2202 - acc: 0.9196Epoch 00019: val_loss did not improve
# 527766/527766 [==============================] - 59s 113us/step - loss: 0.2202 - acc: 0.9196 - val_loss: 0.2419 - val_acc: 0.9257
# Epoch 20/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2209 - acc: 0.9197Epoch 00020: val_loss did not improve
# 527766/527766 [==============================] - 60s 114us/step - loss: 0.2209 - acc: 0.9197 - val_loss: 0.2430 - val_acc: 0.9255
# Epoch 21/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2199 - acc: 0.9200Epoch 00021: val_loss did not improve
# 527766/527766 [==============================] - 59s 113us/step - loss: 0.2199 - acc: 0.9200 - val_loss: 0.2437 - val_acc: 0.9249
# Epoch 22/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2196 - acc: 0.9201Epoch 00022: val_loss did not improve
# 527766/527766 [==============================] - 59s 112us/step - loss: 0.2196 - acc: 0.9201 - val_loss: 0.2463 - val_acc: 0.9249
# Epoch 23/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2193 - acc: 0.9200Epoch 00023: val_loss did not improve
# 527766/527766 [==============================] - 59s 112us/step - loss: 0.2193 - acc: 0.9200 - val_loss: 0.2447 - val_acc: 0.9244
# Epoch 24/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2193 - acc: 0.9197Epoch 00024: val_loss did not improve
# 527766/527766 [==============================] - 59s 112us/step - loss: 0.2193 - acc: 0.9197 - val_loss: 0.2490 - val_acc: 0.9247
# Epoch 25/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2201 - acc: 0.9197Epoch 00025: val_loss did not improve
# 527766/527766 [==============================] - 59s 112us/step - loss: 0.2201 - acc: 0.9197 - val_loss: 0.2485 - val_acc: 0.9248
# Epoch 26/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2192 - acc: 0.9198Epoch 00026: val_loss did not improve
# 527766/527766 [==============================] - 59s 112us/step - loss: 0.2192 - acc: 0.9198 - val_loss: 0.2481 - val_acc: 0.9248
# Epoch 27/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2187 - acc: 0.9199Epoch 00027: val_loss did not improve
# 527766/527766 [==============================] - 59s 111us/step - loss: 0.2187 - acc: 0.9199 - val_loss: 0.2481 - val_acc: 0.9246
# Epoch 28/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2190 - acc: 0.9197Epoch 00028: val_loss did not improve
# 527766/527766 [==============================] - 59s 112us/step - loss: 0.2190 - acc: 0.9197 - val_loss: 0.2519 - val_acc: 0.9246
# Epoch 29/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2191 - acc: 0.9197Epoch 00029: val_loss did not improve
# 527766/527766 [==============================] - 59s 113us/step - loss: 0.2191 - acc: 0.9197 - val_loss: 0.2479 - val_acc: 0.9243
# Epoch 30/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2190 - acc: 0.9198Epoch 00030: val_loss did not improve
# 527766/527766 [==============================] - 63s 120us/step - loss: 0.2191 - acc: 0.9198 - val_loss: 0.2507 - val_acc: 0.9243
# Epoch 31/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2191 - acc: 0.9200Epoch 00031: val_loss did not improve
# 527766/527766 [==============================] - 58s 110us/step - loss: 0.2191 - acc: 0.9200 - val_loss: 0.2517 - val_acc: 0.9245
# Epoch 32/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2190 - acc: 0.9200Epoch 00032: val_loss did not improve
# 527766/527766 [==============================] - 59s 112us/step - loss: 0.2190 - acc: 0.9200 - val_loss: 0.2492 - val_acc: 0.9249
# Epoch 33/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2184 - acc: 0.9201Epoch 00033: val_loss did not improve
# 527766/527766 [==============================] - 60s 113us/step - loss: 0.2184 - acc: 0.9201 - val_loss: 0.2485 - val_acc: 0.9242
# Epoch 34/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2182 - acc: 0.9201Epoch 00034: val_loss did not improve
# 527766/527766 [==============================] - 59s 113us/step - loss: 0.2183 - acc: 0.9201 - val_loss: 0.2491 - val_acc: 0.9246
# Epoch 35/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2183 - acc: 0.9202Epoch 00035: val_loss did not improve
# 527766/527766 [==============================] - 61s 116us/step - loss: 0.2184 - acc: 0.9202 - val_loss: 0.2470 - val_acc: 0.9239
# Epoch 36/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2188 - acc: 0.9202Epoch 00036: val_loss did not improve
# 527766/527766 [==============================] - 58s 110us/step - loss: 0.2188 - acc: 0.9202 - val_loss: 0.2504 - val_acc: 0.9242
# Epoch 37/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2180 - acc: 0.9204Epoch 00037: val_loss did not improve
# 527766/527766 [==============================] - 59s 111us/step - loss: 0.2180 - acc: 0.9204 - val_loss: 0.2521 - val_acc: 0.9242
# Epoch 38/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2181 - acc: 0.9200Epoch 00038: val_loss did not improve
# 527766/527766 [==============================] - 58s 111us/step - loss: 0.2181 - acc: 0.9200 - val_loss: 0.2486 - val_acc: 0.9235
# Epoch 39/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2177 - acc: 0.9202Epoch 00039: val_loss did not improve
# 527766/527766 [==============================] - 58s 110us/step - loss: 0.2177 - acc: 0.9202 - val_loss: 0.2442 - val_acc: 0.9239
# Epoch 40/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2177 - acc: 0.9201Epoch 00040: val_loss did not improve
# 527766/527766 [==============================] - 59s 112us/step - loss: 0.2177 - acc: 0.9200 - val_loss: 0.2473 - val_acc: 0.9242
# Epoch 41/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2176 - acc: 0.9203Epoch 00041: val_loss did not improve
# 527766/527766 [==============================] - 59s 112us/step - loss: 0.2177 - acc: 0.9203 - val_loss: 0.2456 - val_acc: 0.9241
# Epoch 42/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2186 - acc: 0.9201Epoch 00042: val_loss did not improve
# 527766/527766 [==============================] - 60s 113us/step - loss: 0.2186 - acc: 0.9201 - val_loss: 0.2499 - val_acc: 0.9240
# Epoch 43/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2178 - acc: 0.9205Epoch 00043: val_loss did not improve
# 527766/527766 [==============================] - 60s 114us/step - loss: 0.2178 - acc: 0.9204 - val_loss: 0.2474 - val_acc: 0.9241
# Epoch 44/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2184 - acc: 0.9201Epoch 00044: val_loss did not improve
# 527766/527766 [==============================] - 659s 1ms/step - loss: 0.2184 - acc: 0.9201 - val_loss: 0.2498 - val_acc: 0.9241
# Epoch 45/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2180 - acc: 0.9207Epoch 00045: val_loss did not improve
# 527766/527766 [==============================] - 480s 909us/step - loss: 0.2180 - acc: 0.9207 - val_loss: 0.2505 - val_acc: 0.9239
# Epoch 46/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2169 - acc: 0.9202Epoch 00046: val_loss did not improve
# 527766/527766 [==============================] - 227s 429us/step - loss: 0.2168 - acc: 0.9202 - val_loss: 0.2516 - val_acc: 0.9232
# Epoch 47/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2174 - acc: 0.9204Epoch 00047: val_loss did not improve
# 527766/527766 [==============================] - 65s 122us/step - loss: 0.2174 - acc: 0.9204 - val_loss: 0.2500 - val_acc: 0.9240
# Epoch 48/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2170 - acc: 0.9203Epoch 00048: val_loss did not improve
# 527766/527766 [==============================] - 60s 114us/step - loss: 0.2170 - acc: 0.9203 - val_loss: 0.2474 - val_acc: 0.9239
# Epoch 49/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2180 - acc: 0.9200Epoch 00049: val_loss did not improve
# 527766/527766 [==============================] - 62s 117us/step - loss: 0.2180 - acc: 0.9200 - val_loss: 0.2494 - val_acc: 0.9234
# Epoch 50/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2178 - acc: 0.9206Epoch 00050: val_loss did not improve
# 527766/527766 [==============================] - 59s 111us/step - loss: 0.2178 - acc: 0.9206 - val_loss: 0.2488 - val_acc: 0.9238
# Epoch 51/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2168 - acc: 0.9206Epoch 00051: val_loss did not improve
# 527766/527766 [==============================] - 59s 112us/step - loss: 0.2168 - acc: 0.9206 - val_loss: 0.2492 - val_acc: 0.9239
# Epoch 52/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2168 - acc: 0.9210Epoch 00052: val_loss did not improve
# 527766/527766 [==============================] - 59s 112us/step - loss: 0.2168 - acc: 0.9210 - val_loss: 0.2506 - val_acc: 0.9240
# Epoch 53/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2176 - acc: 0.9207Epoch 00053: val_loss did not improve
# 527766/527766 [==============================] - 59s 112us/step - loss: 0.2175 - acc: 0.9207 - val_loss: 0.2468 - val_acc: 0.9237
# Epoch 54/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2171 - acc: 0.9205Epoch 00054: val_loss did not improve
# 527766/527766 [==============================] - 60s 114us/step - loss: 0.2171 - acc: 0.9205 - val_loss: 0.2512 - val_acc: 0.9234
# Epoch 55/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2172 - acc: 0.9205Epoch 00055: val_loss did not improve
# 527766/527766 [==============================] - 64s 122us/step - loss: 0.2172 - acc: 0.9205 - val_loss: 0.2528 - val_acc: 0.9235
# Epoch 56/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2169 - acc: 0.9206Epoch 00056: val_loss did not improve
# 527766/527766 [==============================] - 66s 125us/step - loss: 0.2169 - acc: 0.9207 - val_loss: 0.2519 - val_acc: 0.9238
# Epoch 57/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2174 - acc: 0.9201Epoch 00057: val_loss did not improve
# 527766/527766 [==============================] - 63s 119us/step - loss: 0.2174 - acc: 0.9201 - val_loss: 0.2534 - val_acc: 0.9238
# Epoch 58/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2169 - acc: 0.9206Epoch 00058: val_loss did not improve
# 527766/527766 [==============================] - 72s 137us/step - loss: 0.2169 - acc: 0.9207 - val_loss: 0.2517 - val_acc: 0.9236
# Epoch 59/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2169 - acc: 0.9207Epoch 00059: val_loss did not improve
# 527766/527766 [==============================] - 79s 150us/step - loss: 0.2169 - acc: 0.9207 - val_loss: 0.2535 - val_acc: 0.9233
# Epoch 60/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2163 - acc: 0.9209Epoch 00060: val_loss did not improve
# 527766/527766 [==============================] - 92s 173us/step - loss: 0.2164 - acc: 0.9208 - val_loss: 0.2530 - val_acc: 0.9234
# Epoch 61/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2172 - acc: 0.9201Epoch 00061: val_loss did not improve
# 527766/527766 [==============================] - 87s 165us/step - loss: 0.2171 - acc: 0.9201 - val_loss: 0.2552 - val_acc: 0.9237
# Epoch 62/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2166 - acc: 0.9208Epoch 00062: val_loss did not improve
# 527766/527766 [==============================] - 97s 185us/step - loss: 0.2166 - acc: 0.9208 - val_loss: 0.2539 - val_acc: 0.9235
# Epoch 63/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2168 - acc: 0.9203Epoch 00063: val_loss did not improve
# 527766/527766 [==============================] - 93s 177us/step - loss: 0.2168 - acc: 0.9203 - val_loss: 0.2522 - val_acc: 0.9238
# Epoch 64/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2164 - acc: 0.9205Epoch 00064: val_loss did not improve
# 527766/527766 [==============================] - 82s 155us/step - loss: 0.2164 - acc: 0.9205 - val_loss: 0.2551 - val_acc: 0.9238
# Epoch 65/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2166 - acc: 0.9202Epoch 00065: val_loss did not improve
# 527766/527766 [==============================] - 78s 147us/step - loss: 0.2166 - acc: 0.9202 - val_loss: 0.2566 - val_acc: 0.9235
# Epoch 66/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2166 - acc: 0.9207Epoch 00066: val_loss did not improve
# 527766/527766 [==============================] - 89s 168us/step - loss: 0.2166 - acc: 0.9207 - val_loss: 0.2534 - val_acc: 0.9238
# Epoch 67/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2167 - acc: 0.9205Epoch 00067: val_loss did not improve
# 527766/527766 [==============================] - 95s 180us/step - loss: 0.2167 - acc: 0.9205 - val_loss: 0.2540 - val_acc: 0.9237
# Epoch 68/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2169 - acc: 0.9203Epoch 00068: val_loss did not improve
# 527766/527766 [==============================] - 89s 169us/step - loss: 0.2169 - acc: 0.9203 - val_loss: 0.2540 - val_acc: 0.9236
# Epoch 69/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2165 - acc: 0.9204Epoch 00069: val_loss did not improve
# 527766/527766 [==============================] - 77s 146us/step - loss: 0.2166 - acc: 0.9204 - val_loss: 0.2554 - val_acc: 0.9237
# Epoch 70/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2163 - acc: 0.9206Epoch 00070: val_loss did not improve
# 527766/527766 [==============================] - 92s 175us/step - loss: 0.2162 - acc: 0.9206 - val_loss: 0.2542 - val_acc: 0.9236
# Epoch 71/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2164 - acc: 0.9206Epoch 00071: val_loss did not improve
# 527766/527766 [==============================] - 80s 151us/step - loss: 0.2165 - acc: 0.9206 - val_loss: 0.2535 - val_acc: 0.9236
# Epoch 72/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2163 - acc: 0.9203Epoch 00072: val_loss did not improve
# 527766/527766 [==============================] - 68s 129us/step - loss: 0.2163 - acc: 0.9203 - val_loss: 0.2550 - val_acc: 0.9236
# Epoch 73/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2168 - acc: 0.9205Epoch 00073: val_loss did not improve
# 527766/527766 [==============================] - 54s 103us/step - loss: 0.2168 - acc: 0.9205 - val_loss: 0.2530 - val_acc: 0.9239
# Epoch 74/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2160 - acc: 0.9200Epoch 00074: val_loss did not improve
# 527766/527766 [==============================] - 58s 110us/step - loss: 0.2160 - acc: 0.9200 - val_loss: 0.2540 - val_acc: 0.9235
# Epoch 75/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2160 - acc: 0.9209Epoch 00075: val_loss did not improve
# 527766/527766 [==============================] - 55s 105us/step - loss: 0.2160 - acc: 0.9209 - val_loss: 0.2545 - val_acc: 0.9237
# Epoch 76/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2162 - acc: 0.9203Epoch 00076: val_loss did not improve
# 527766/527766 [==============================] - 65s 124us/step - loss: 0.2162 - acc: 0.9203 - val_loss: 0.2553 - val_acc: 0.9239
# Epoch 77/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2164 - acc: 0.9207Epoch 00077: val_loss did not improve
# 527766/527766 [==============================] - 63s 119us/step - loss: 0.2164 - acc: 0.9207 - val_loss: 0.2569 - val_acc: 0.9237
# Epoch 78/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2169 - acc: 0.9206Epoch 00078: val_loss did not improve
# 527766/527766 [==============================] - 69s 130us/step - loss: 0.2169 - acc: 0.9206 - val_loss: 0.2542 - val_acc: 0.9237
# Epoch 79/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2161 - acc: 0.9204Epoch 00079: val_loss did not improve
# 527766/527766 [==============================] - 74s 140us/step - loss: 0.2161 - acc: 0.9204 - val_loss: 0.2552 - val_acc: 0.9237
# Epoch 80/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2165 - acc: 0.9207Epoch 00080: val_loss did not improve
# 527766/527766 [==============================] - 65s 124us/step - loss: 0.2165 - acc: 0.9207 - val_loss: 0.2552 - val_acc: 0.9238
# Epoch 81/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2163 - acc: 0.9207Epoch 00081: val_loss did not improve
# 527766/527766 [==============================] - 67s 127us/step - loss: 0.2163 - acc: 0.9208 - val_loss: 0.2548 - val_acc: 0.9236
# Epoch 82/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2164 - acc: 0.9202Epoch 00082: val_loss did not improve
# 527766/527766 [==============================] - 57s 108us/step - loss: 0.2164 - acc: 0.9202 - val_loss: 0.2573 - val_acc: 0.9236
# Epoch 83/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2160 - acc: 0.9205Epoch 00083: val_loss did not improve
# 527766/527766 [==============================] - 60s 113us/step - loss: 0.2159 - acc: 0.9205 - val_loss: 0.2540 - val_acc: 0.9237
# Epoch 84/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2161 - acc: 0.9200Epoch 00084: val_loss did not improve
# 527766/527766 [==============================] - 77s 145us/step - loss: 0.2162 - acc: 0.9200 - val_loss: 0.2587 - val_acc: 0.9237
# Epoch 85/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2162 - acc: 0.9203Epoch 00085: val_loss did not improve
# 527766/527766 [==============================] - 77s 146us/step - loss: 0.2161 - acc: 0.9203 - val_loss: 0.2558 - val_acc: 0.9235
# Epoch 86/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2169 - acc: 0.9203Epoch 00086: val_loss did not improve
# 527766/527766 [==============================] - 67s 126us/step - loss: 0.2169 - acc: 0.9203 - val_loss: 0.2586 - val_acc: 0.9234
# Epoch 87/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2164 - acc: 0.9204Epoch 00087: val_loss did not improve
# 527766/527766 [==============================] - 59s 111us/step - loss: 0.2165 - acc: 0.9204 - val_loss: 0.2569 - val_acc: 0.9236
# Epoch 88/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2160 - acc: 0.9204Epoch 00088: val_loss did not improve
# 527766/527766 [==============================] - 57s 108us/step - loss: 0.2160 - acc: 0.9204 - val_loss: 0.2576 - val_acc: 0.9236
# Epoch 89/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2158 - acc: 0.9204Epoch 00089: val_loss did not improve
# 527766/527766 [==============================] - 53s 100us/step - loss: 0.2158 - acc: 0.9204 - val_loss: 0.2575 - val_acc: 0.9237
# Epoch 90/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2157 - acc: 0.9207Epoch 00090: val_loss did not improve
# 527766/527766 [==============================] - 54s 103us/step - loss: 0.2157 - acc: 0.9207 - val_loss: 0.2540 - val_acc: 0.9235
# Epoch 91/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2162 - acc: 0.9206Epoch 00091: val_loss did not improve
# 527766/527766 [==============================] - 55s 104us/step - loss: 0.2162 - acc: 0.9206 - val_loss: 0.2541 - val_acc: 0.9236
# Epoch 92/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2157 - acc: 0.9202Epoch 00092: val_loss did not improve
# 527766/527766 [==============================] - 55s 105us/step - loss: 0.2158 - acc: 0.9202 - val_loss: 0.2573 - val_acc: 0.9234
# Epoch 93/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2161 - acc: 0.9204Epoch 00093: val_loss did not improve
# 527766/527766 [==============================] - 57s 107us/step - loss: 0.2161 - acc: 0.9204 - val_loss: 0.2581 - val_acc: 0.9234
# Epoch 94/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2160 - acc: 0.9202Epoch 00094: val_loss did not improve
# 527766/527766 [==============================] - 55s 105us/step - loss: 0.2160 - acc: 0.9202 - val_loss: 0.2569 - val_acc: 0.9234
# Epoch 95/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2158 - acc: 0.9205Epoch 00095: val_loss did not improve
# 527766/527766 [==============================] - 56s 107us/step - loss: 0.2158 - acc: 0.9205 - val_loss: 0.2572 - val_acc: 0.9234
# Epoch 96/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2164 - acc: 0.9202Epoch 00096: val_loss did not improve
# 527766/527766 [==============================] - 57s 109us/step - loss: 0.2164 - acc: 0.9202 - val_loss: 0.2589 - val_acc: 0.9235
# Epoch 97/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2154 - acc: 0.9206Epoch 00097: val_loss did not improve
# 527766/527766 [==============================] - 56s 106us/step - loss: 0.2154 - acc: 0.9206 - val_loss: 0.2584 - val_acc: 0.9235
# Epoch 98/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2159 - acc: 0.9206Epoch 00098: val_loss did not improve
# 527766/527766 [==============================] - 55s 105us/step - loss: 0.2159 - acc: 0.9206 - val_loss: 0.2567 - val_acc: 0.9236
# Epoch 99/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2160 - acc: 0.9202Epoch 00099: val_loss did not improve
# 527766/527766 [==============================] - 58s 111us/step - loss: 0.2160 - acc: 0.9202 - val_loss: 0.2565 - val_acc: 0.9235
# Epoch 100/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2152 - acc: 0.9207Epoch 00100: val_loss did not improve
# 527766/527766 [==============================] - 73s 139us/step - loss: 0.2152 - acc: 0.9207 - val_loss: 0.2567 - val_acc: 0.9235
# Epoch 101/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2158 - acc: 0.9205Epoch 00101: val_loss did not improve
# 527766/527766 [==============================] - 74s 140us/step - loss: 0.2157 - acc: 0.9205 - val_loss: 0.2549 - val_acc: 0.9236
# Epoch 102/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2158 - acc: 0.9205Epoch 00102: val_loss did not improve
# 527766/527766 [==============================] - 78s 147us/step - loss: 0.2158 - acc: 0.9205 - val_loss: 0.2575 - val_acc: 0.9236
# Epoch 103/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2159 - acc: 0.9203Epoch 00103: val_loss did not improve
# 527766/527766 [==============================] - 74s 141us/step - loss: 0.2159 - acc: 0.9203 - val_loss: 0.2584 - val_acc: 0.9236
# Epoch 104/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2152 - acc: 0.9206Epoch 00104: val_loss did not improve
# 527766/527766 [==============================] - 65s 123us/step - loss: 0.2152 - acc: 0.9206 - val_loss: 0.2556 - val_acc: 0.9234
# Epoch 105/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2156 - acc: 0.9203Epoch 00105: val_loss did not improve
# 527766/527766 [==============================] - 72s 137us/step - loss: 0.2156 - acc: 0.9203 - val_loss: 0.2611 - val_acc: 0.9232
# Epoch 106/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2159 - acc: 0.9203Epoch 00106: val_loss did not improve
# 527766/527766 [==============================] - 73s 138us/step - loss: 0.2160 - acc: 0.9203 - val_loss: 0.2589 - val_acc: 0.9233
# Epoch 107/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2161 - acc: 0.9205Epoch 00107: val_loss did not improve
# 527766/527766 [==============================] - 72s 136us/step - loss: 0.2161 - acc: 0.9205 - val_loss: 0.2570 - val_acc: 0.9234
# Epoch 108/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2162 - acc: 0.9206Epoch 00108: val_loss did not improve
# 527766/527766 [==============================] - 59s 112us/step - loss: 0.2162 - acc: 0.9206 - val_loss: 0.2605 - val_acc: 0.9233
# Epoch 109/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2155 - acc: 0.9206Epoch 00109: val_loss did not improve
# 527766/527766 [==============================] - 55s 105us/step - loss: 0.2155 - acc: 0.9206 - val_loss: 0.2600 - val_acc: 0.9235
# Epoch 110/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2155 - acc: 0.9207Epoch 00110: val_loss did not improve
# 527766/527766 [==============================] - 64s 121us/step - loss: 0.2155 - acc: 0.9207 - val_loss: 0.2576 - val_acc: 0.9235
# Epoch 111/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2154 - acc: 0.9206Epoch 00111: val_loss did not improve
# 527766/527766 [==============================] - 59s 111us/step - loss: 0.2154 - acc: 0.9206 - val_loss: 0.2597 - val_acc: 0.9235
# Epoch 112/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2159 - acc: 0.9206Epoch 00112: val_loss did not improve
# 527766/527766 [==============================] - 53s 100us/step - loss: 0.2159 - acc: 0.9207 - val_loss: 0.2592 - val_acc: 0.9235
# Epoch 113/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2160 - acc: 0.9204Epoch 00113: val_loss did not improve
# 527766/527766 [==============================] - 52s 99us/step - loss: 0.2160 - acc: 0.9204 - val_loss: 0.2587 - val_acc: 0.9236
# Epoch 114/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2156 - acc: 0.9207Epoch 00114: val_loss did not improve
# 527766/527766 [==============================] - 53s 100us/step - loss: 0.2156 - acc: 0.9207 - val_loss: 0.2568 - val_acc: 0.9236
# Epoch 115/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2153 - acc: 0.9207Epoch 00115: val_loss did not improve
# 527766/527766 [==============================] - 52s 99us/step - loss: 0.2153 - acc: 0.9207 - val_loss: 0.2564 - val_acc: 0.9236
# Epoch 116/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2159 - acc: 0.9202Epoch 00116: val_loss did not improve
# 527766/527766 [==============================] - 53s 100us/step - loss: 0.2159 - acc: 0.9202 - val_loss: 0.2589 - val_acc: 0.9236
# Epoch 117/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2146 - acc: 0.9207Epoch 00117: val_loss did not improve
# 527766/527766 [==============================] - 53s 100us/step - loss: 0.2146 - acc: 0.9207 - val_loss: 0.2575 - val_acc: 0.9236
# Epoch 118/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2154 - acc: 0.9203Epoch 00118: val_loss did not improve
# 527766/527766 [==============================] - 53s 100us/step - loss: 0.2154 - acc: 0.9203 - val_loss: 0.2583 - val_acc: 0.9237
# Epoch 119/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2154 - acc: 0.9205Epoch 00119: val_loss did not improve
# 527766/527766 [==============================] - 52s 99us/step - loss: 0.2154 - acc: 0.9205 - val_loss: 0.2597 - val_acc: 0.9236
# Epoch 120/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2158 - acc: 0.9204Epoch 00120: val_loss did not improve
# 527766/527766 [==============================] - 53s 100us/step - loss: 0.2158 - acc: 0.9204 - val_loss: 0.2570 - val_acc: 0.9236
# Epoch 121/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2156 - acc: 0.9205Epoch 00121: val_loss did not improve
# 527766/527766 [==============================] - 53s 100us/step - loss: 0.2156 - acc: 0.9205 - val_loss: 0.2575 - val_acc: 0.9239
# Epoch 122/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2151 - acc: 0.9208Epoch 00122: val_loss did not improve
# 527766/527766 [==============================] - 52s 99us/step - loss: 0.2151 - acc: 0.9208 - val_loss: 0.2583 - val_acc: 0.9237
# Epoch 123/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2157 - acc: 0.9205Epoch 00123: val_loss did not improve
# 527766/527766 [==============================] - 53s 100us/step - loss: 0.2157 - acc: 0.9205 - val_loss: 0.2587 - val_acc: 0.9237
# Epoch 124/124
# 527360/527766 [============================>.] - ETA: 0s - loss: 0.2155 - acc: 0.9202Epoch 00124: val_loss did not improve
# 527766/527766 [==============================] - 53s 100us/step - loss: 0.2155 - acc: 0.9202 - val_loss: 0.2593 - val_acc: 0.9237
# Time: 153.63 minutes

# %%
plt.plot(history.history['loss'], 'k-', label='train');
plt.plot(history.history['val_loss'], 'r-', label='valid');
plt.xlabel('epochs');
plt.ylabel('Loss (binary cross-entropy)')
#plt.yscale('log');
plt.legend(loc='best');

# %%
plt.plot(history.history['acc'], 'k-', label='train');
plt.plot(history.history['val_acc'], 'r-', label='valid');
plt.xlabel('epochs');
plt.ylabel('Accuracy')
#plt.yscale('log');
plt.legend(loc='best');

# %%
this_run = np.mean(history.history['val_loss'][-50:])
print('This run: %.5f' % this_run)

if this_run < best_val_loss:
    print('New Best Model Found!\n')
    best_val_loss = this_run
    train_loss_of_best = np.mean(history.history['loss'][-50:])
    best_params = get_params()
print('Best validation loss so far: %.5f' % best_val_loss)
print('Training loss of same model: %.5f' % train_loss_of_best)
print('Best hyperparameters found so far:')
pprint(best_params)
# Out:
# This run: 0.25729
# Best validation loss so far: 0.19070
# Training loss of same model: 0.27901
# Best hyperparameters found so far:
# {'BATCH_SIZE': 1024,
#  'BETA_1': 0.9,
#  'BETA_2': 0.999,
#  'DECAY': 0.01,
#  'DROPOUT': 0.5,
#  'EPOCHS': 124,
#  'EPSILON': 1e-08,
#  'ETA': 0.1,
#  'NODES_PER_LAYER': [20, 40, 80, 160, 160, 160, 160, 160, 80, 40, 20, 2]}

# %%
preds = model.predict(X_test)
pred_probs = util.preds2probs(preds)
preds = util.one_cold(util.binarize(preds))
y_test_cold = util.one_cold((y_test))
cm = util.make_confusion_matrix(y_test_cold, pred_probs, 0.5)
# Out:
# Confusion Matrix:
#          Predicted:
#          	1		0
# Actual: 1	11088		3670
#         0	4595		98119

# %%
metrics = util.get_metrics(cm)
# Out:
# Accuracy:  0.929642808499
# Precision: 0.707007587834
# Recall:    0.751321317252
# F1:        0.728491179659

# %%
auc_metrics = util.get_auc(y_test_cold, pred_probs)
# Out:
# AUC:       0.952086056931

# %%
util.plot_roc(auc_metrics['fpr'], auc_metrics['tpr'])

# %%
def column2matrix(dataframe, column, cell_dim=10000):
    '''                                                                          
    Convert a column from DataFrame df into a matrix representation with the     
    upper-left cell indexing beginning at [0, 0].                                
    It is expected that the DataFrame has columns x and y.                       
                                                                                 
    Args:                                                                        
    df: DataFrame: the source data                                               
    column: string: the column name to extract                                   
    cel_dim: numeric: the dimensions of each grid cell                           
                                                                                 
    Returns: np.ndarray (a 2D list; matrix)                                      
    '''
    df = dataframe.copy()
    x_min = df.x.min()
    y_min = df.y.min()
    df.x -= x_min
    df.y -= y_min
    xs = sorted(df.x.unique())
    ys = sorted(df.y.unique())
    matrix = np.array([[np.nan for y in range(len(ys))]
                       for x in range(len(xs))])

    for row in df.index:
        x, y, value = df.loc[row, ['x', 'y', column]]
        i = int((x - xs[0]) / cell_dim)
        j = int((y - ys[0]) / cell_dim)
        matrix[i, j] = value

    return matrix

# %%
#print(len(y_test_cold))
#print(full_test.shape)
full_test['preds'] = preds
full_test.head()
# Out:
#    year  meanTemp_Annual  meanTemp_AprAug  meanTemp_Aug  meanMinTemp_DecFeb  \
# 0  2000        17.057845        18.892138     21.608865            4.831345
# 1  2000        17.254652        19.109267     21.808772            5.056313
# 2  2000        17.676624        19.746520     22.608925            4.883052
# 3  2000        16.558509        18.864768     22.112176            3.356400
# 4  2000        16.781979        19.328211     22.731819            3.201135
#
#    meanMinTemp_Oct  meanMinTemp_Jan  meanMinTemp_Mar  meanMaxTemp_Aug  \
# 0        10.825336         6.119776         7.627907        27.147665
# 1        11.052817         6.231007         7.827016        27.346988
# 2        11.081191         6.041158         7.776271        28.596847
# 3         9.556494         4.649940         6.029264        28.749263
# 4         9.459611         4.256498         5.852778        29.813080
#
#    precip_meanAnnual  ...    varPrecip_growingSeason  elev_etopo1        lat  \
# 0           7.199924  ...                   0.674441           52  30.505152
# 1           6.621443  ...                   0.790828           17  30.523203
# 2           6.506222  ...                   1.732051          151  30.541141
# 3           9.937936  ...                   0.172152          500  30.558965
# 4           9.939182  ...                   0.364632          564  30.576676
#
#           lon  studyArea  elev_srtm30          x          y  beetle  preds
# 0 -116.039726          1           -2 -1550000.0 -2000000.0       0      0
# 1 -115.938118          1           17 -1540000.0 -2000000.0       0      0
# 2 -115.836475          1           74 -1530000.0 -2000000.0       0      0
# 3 -115.734797          1          466 -1520000.0 -2000000.0       0      0
# 4 -115.633085          1          568 -1510000.0 -2000000.0       0      0
#
# [5 rows x 26 columns]

# %%
test_2000 = full_test.loc[full_test.year == 2000, :]
test_2001 = full_test.loc[full_test.year == 2001, :]
test_2002 = full_test.loc[full_test.year == 2002, :]
test_2000.head()
# Out:
#    year  meanTemp_Annual  meanTemp_AprAug  meanTemp_Aug  meanMinTemp_DecFeb  \
# 0  2000        17.057845        18.892138     21.608865            4.831345
# 1  2000        17.254652        19.109267     21.808772            5.056313
# 2  2000        17.676624        19.746520     22.608925            4.883052
# 3  2000        16.558509        18.864768     22.112176            3.356400
# 4  2000        16.781979        19.328211     22.731819            3.201135
#
#    meanMinTemp_Oct  meanMinTemp_Jan  meanMinTemp_Mar  meanMaxTemp_Aug  \
# 0        10.825336         6.119776         7.627907        27.147665
# 1        11.052817         6.231007         7.827016        27.346988
# 2        11.081191         6.041158         7.776271        28.596847
# 3         9.556494         4.649940         6.029264        28.749263
# 4         9.459611         4.256498         5.852778        29.813080
#
#    precip_meanAnnual  ...    varPrecip_growingSeason  elev_etopo1        lat  \
# 0           7.199924  ...                   0.674441           52  30.505152
# 1           6.621443  ...                   0.790828           17  30.523203
# 2           6.506222  ...                   1.732051          151  30.541141
# 3           9.937936  ...                   0.172152          500  30.558965
# 4           9.939182  ...                   0.364632          564  30.576676
#
#           lon  studyArea  elev_srtm30          x          y  beetle  preds
# 0 -116.039726          1           -2 -1550000.0 -2000000.0       0      0
# 1 -115.938118          1           17 -1540000.0 -2000000.0       0      0
# 2 -115.836475          1           74 -1530000.0 -2000000.0       0      0
# 3 -115.734797          1          466 -1520000.0 -2000000.0       0      0
# 4 -115.633085          1          568 -1510000.0 -2000000.0       0      0
#
# [5 rows x 26 columns]

# %%
beetle_2000_matrix = column2matrix(test_2000, 'beetle')

# %%
pred_2000_matrix = column2matrix(test_2000, 'preds')
error_matrix = pred_2000_matrix - beetle_2000_matrix

# %%
imshow(np.rot90(beetle_2000_matrix));

# %%
imshow(np.rot90(pred_2000_matrix));

# %%
imshow(np.rot90(error_matrix));

# %%
beetle_2002_matrix = column2matrix(test_2002, 'beetle')
pred_2002_matrix = column2matrix(test_2002, 'preds')
error_matrix_2002 = pred_2002_matrix - beetle_2002_matrix

# %%
imshow(np.rot90(beetle_2002_matrix));

# %%
imshow(np.rot90(pred_2002_matrix));

# %%
imshow(np.rot90(error_matrix_2002));

# %%
list(test_2000)
# Out:
# ['year',
#  'meanTemp_Annual',
#  'meanTemp_AprAug',
#  'meanTemp_Aug',
#  'meanMinTemp_DecFeb',
#  'meanMinTemp_Oct',
#  'meanMinTemp_Jan',
#  'meanMinTemp_Mar',
#  'meanMaxTemp_Aug',
#  'precip_meanAnnual',
#  'precip_JunAug',
#  'vegetation',
#  'precipPrevious_JunAug',
#  'precip_OctSep',
#  'precipPrevious_OctSep',
#  'precip_growingSeason',
#  'varPrecip_growingSeason',
#  'elev_etopo1',
#  'lat',
#  'lon',
#  'studyArea',
#  'elev_srtm30',
#  'x',
#  'y',
#  'beetle',
#  'preds']

# %%
fields = [
    'meanTemp_Annual', 'meanTemp_AprAug', 'meanTemp_Aug', 
    'meanMinTemp_DecFeb', 'meanMinTemp_Oct', 'meanMinTemp_Jan',
    'meanMinTemp_Mar', 'meanMaxTemp_Aug', 'precip_meanAnnual', 
    'precip_JunAug', 'vegetation', 'precipPrevious_JunAug', 
    'precip_OctSep', 'precipPrevious_OctSep', 'precip_growingSeason',
    'varPrecip_growingSeason', 'elev_etopo1']
for field in fields:
    field_2000_matrix = column2matrix(test_2000, field)
    plt.figure();
    imshow(np.rot90(field_2000_matrix));
    plt.title(field + ' (2000)');
    plt.show();
